# %% [markdown]
# # 1. The basics - making an API request

# %%
# !pip3 install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (21.2.4)
# Collecting pip
#   Using cached pip-24.1.2-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 21.2.4
#     Uninstalling pip-21.2.4:
#       Successfully uninstalled pip-21.2.4
# Successfully installed pip-24.1.2

# %%
# !pip3 install openai python-dotenv streamlit
# Out:
# Requirement already satisfied: openai in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (1.35.14)
# Collecting python-dotenv
#   Using cached python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: certifi in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Using cached python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1

# %%
# import required packages

from openai import OpenAI
import json
from dotenv import load_dotenv
from pprint import pprint
import re

load_dotenv()
# Out:
# True

# %%
client = OpenAI()

# %% [markdown]
# ### Basic chat completion

# %%
completion = client.chat.completions.create(
  model="gpt-3.5-turbo-0125",
  messages=[
    {"role": "system", "content": "You are an expert fitness trainer that specializes in helping people prep for the first competitive event."},
    {"role": "user", "content": "Provide me with a training plan to prepare for my 5k in 4 weeks. I want to run it in under 28 minutes."}
  ],
  temperature=1,
  max_tokens=1024,
  seed=42
  
)
print(completion.choices[0].message.content)
# Out:
# Sure, I can definitely help you with that! Here's a 4-week training plan to help you prepare for your 5k and achieve your goal of running it in under 28 minutes:
#
# **Week 1:**
# - Monday: 20-minute easy run
# - Tuesday: 30 minutes of interval training (1 min hard running, 1 min walking/jogging x 10)
# - Wednesday: Rest or cross-training (yoga, cycling, swimming)
# - Thursday: 3x800m repeats with 2 minutes rest in between each
# - Friday: Rest
# - Saturday: 25-minute tempo run at a challenging pace
# - Sunday: Easy 3-mile run
#
# **Week 2:**
# - Monday: 25-minute easy run
# - Tuesday: 35 minutes of interval training (2 min hard running, 1 min walking/jogging x 8)
# - Wednesday: Rest or cross-training
# - Thursday: 4x800m repeats with 2 minutes rest in between each
# - Friday: Rest
# - Saturday: 30-minute tempo run at a challenging pace
# - Sunday: Easy 4-mile run
#
# **Week 3:**
# - Monday: 30-minute easy run
# - Tuesday: 40 minutes of interval training (3 min hard running, 1 min walking/jogging x 6)
# - Wednesday: Rest or cross-training
# - Thursday: 5x800m repeats with 2 minutes rest in between each
# - Friday: Rest
# - Saturday: 35-minute tempo run at a challenging pace
# - Sunday: Easy 5-mile run
#
# **Week 4:**
# - Monday: 20-minute easy run
# - Tuesday: 20 minutes of interval training (1 min hard running, 1 min walking/jogging x 10)
# - Wednesday: Rest
# - Thursday: 3x400m repeats with 1 minute rest in between each
# - Friday: Rest
# - Saturday: Rest
# - Sunday: Race day! Run your 5k and crush your goal of finishing under 28 minutes!
#
# Remember to listen to your body, stay hydrated, and fuel yourself with nutritious foods to support your training. Good luck with your 5k! Let me know if you have any questions or need further assistance.

# %%
# view response
pprint(vars(completion))
# Out:
# {'choices': [Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content="Sure, I can definitely help you with that! Here's a 4-week training plan to help you prepare for your 5k and achieve your goal of running it in under 28 minutes:\n\n**Week 1:**\n- Monday: 20-minute easy run\n- Tuesday: 30 minutes of interval training (1 min hard running, 1 min walking/jogging x 10)\n- Wednesday: Rest or cross-training (yoga, cycling, swimming)\n- Thursday: 3x800m repeats with 2 minutes rest in between each\n- Friday: Rest\n- Saturday: 25-minute tempo run at a challenging pace\n- Sunday: Easy 3-mile run\n\n**Week 2:**\n- Monday: 25-minute easy run\n- Tuesday: 35 minutes of interval training (2 min hard running, 1 min walking/jogging x 8)\n- Wednesday: Rest or cross-training\n- Thursday: 4x800m repeats with 2 minutes rest in between each\n- Friday: Rest\n- Saturday: 30-minute tempo run at a challenging pace\n- Sunday: Easy 4-mile run\n\n**Week 3:**\n- Monday: 30-minute easy run\n- Tuesday: 40 minutes of interval training (3 min hard running, 1 min walking/jogging x 6)\n- Wednesday: Rest or cross-training\n- Thursday: 5x800m repeats with 2 minutes rest in between each\n- Friday: Rest\n- Saturday: 35-minute tempo run at a challenging pace\n- Sunday: Easy 5-mile run\n\n**Week 4:**\n- Monday: 20-minute easy run\n- Tuesday: 20 minutes of interval training (1 min hard running, 1 min walking/jogging x 10)\n- Wednesday: Rest\n- Thursday: 3x400m repeats with 1 minute rest in between each\n- Friday: Rest\n- Saturday: Rest\n- Sunday: Race day! Run your 5k and crush your goal of finishing under 28 minutes!\n\nRemember to listen to your body, stay hydrated, and fuel yourself with nutritious foods to support your training. Good luck with your 5k! Let me know if you have any questions or need further assistance.", role='assistant', function_call=None, tool_calls=None))],
#  'created': 1721304788,
#  'id': 'chatcmpl-9mKIOpVrWs421SnRxm1QnGuvcmbb7',
#  'model': 'gpt-3.5-turbo-0125',
#  'object': 'chat.completion',
#  'service_tier': None,
#  'system_fingerprint': None,
#  'usage': CompletionUsage(completion_tokens=467, prompt_tokens=58, total_tokens=525)}

# %% [markdown]
# ### JSON Mode

# %%
completion = client.chat.completions.create(
  model="gpt-3.5-turbo-0125",
  messages=[
    {"role": "system", "content": "You are an expert fitness trainer that specializes in helping people prep for the first competitive event. \
      You respond in a JSON format, where the keys represent weeks and days, and the values contain the training plan."},
    {"role": "user", "content": "Provide me with a training plan to prepare for my 5k in 4 weeks. I want to run it in under 28 minutes."}
  ],
  temperature=1,
  max_tokens=1024,
  seed=42,
  response_format={ "type": "json_object" },
  
)

print(completion.choices[0].message.content)
# Out:
# {
#     "Week 1": {
#         "Day 1": "Easy run for 20 minutes at a comfortable pace",
#         "Day 2": "Interval training - 5 x 1 minute fast running with 2 minutes of walking or jogging in between",
#         "Day 3": "Rest day"
#     },
#     "Week 2": {
#         "Day 1": "Easy run for 25 minutes at a comfortable pace",
#         "Day 2": "Hill repeats - 4 x 1 minute uphill sprints with jog down recovery",
#         "Day 3": "Rest day"
#     },
#     "Week 3": {
#         "Day 1": "Easy run for 30 minutes at a comfortable pace",
#         "Day 2": "Fartlek training - 5 minutes fast running, 2 minutes slow jog, repeat 3 times",
#         "Day 3": "Rest day"
#     },
#     "Week 4": {
#         "Day 1": "Easy run for 20 minutes at a comfortable pace",
#         "Day 2": "Race simulation - Run 2 miles at your goal 5k pace",
#         "Day 3": "Rest day"
#     }
# }

# %% [markdown]
# ### Streaming Mode

# %%
completion = client.chat.completions.create(
  model="gpt-3.5-turbo-0125",
  messages=[
    {"role": "system", "content": "You are an expert fitness trainer that specializes in helping people prep for the first competitive event."},
    {"role": "user", "content": "Provide me with a training plan to prepare for my 5k in 4 weeks. I want to run it in under 28 minutes."}
  ],
  temperature=1,
  max_tokens=1024,
  seed=42,
  stream=True
  
)

for chunk in completion:
  print(chunk.choices[0].delta.content)
# Out:
# Sure
# ,
#  I
#  can
#  definitely
#  help
#  you
#  with
#  that
# !
#  Here
# 's
#  a
#
# 4
# -week
#  training
#  plan
#  to
#  prepare
#  you
#  for
#  your
#
# 5
# k
#  and
#  achieve
#  your
#  goal
#  of
#  running
#  it
#  in
#  under
#
# 28
#  minutes
# :
#
#
# ###
#  Week
#
# 1
# :
#
# -
#  **
# Day
#
# 1
# **:
#
# 2
# -mile
#  easy
#  run
#
#
# -
#  **
# Day
#
# 2
# **:
#  Rest
#  or
#  cross
# -training
#  (
# low
#  impact
# )
#
# -
#  **
# Day
#
# 3
# **:
#  Interval
#  training
#  -
#
# 5
#  x
#
# 400
# m
#  at
#  a
#  fast
#  pace
#  with
#
# 200
# m
#  recovery
#  jog
#  in
#  between
#
#
# -
#  **
# Day
#
# 4
# **:
#  Rest
#  or
#  cross
# -training
#  (
# low
#  impact
# )
#
# -
#  **
# Day
#
# 5
# **:
#
# 2
# -mile
#  easy
#  run
#
#
# -
#  **
# Day
#
# 6
# **:
#  Rest
#
#
# -
#  **
# Day
#
# 7
# **:
#  Long
#  run
#  -
#
# 3
#  miles
#  at
#  a
#  comfortable
#  pace
#
#
#
# ###
#  Week
#
# 2
# :
#
# -
#  **
# Day
#
# 1
# **:
#
# 2
# -mile
#  easy
#  run
#
#
# -
#  **
# Day
#
# 2
# **:
#  Rest
#  or
#  cross
# -training
#  (
# low
#  impact
# )
#
# -
#  **
# Day
#
# 3
# **:
#  F
# art
# lek
#  training
#  -
#
# 30
#  minutes
#  of
#  alternating
#  between
#  a
#  fast
#  pace
#  and
#  a
#  recovery
#  pace
#
#
# -
#  **
# Day
#
# 4
# **:
#  Rest
#  or
#  cross
# -training
#  (
# low
#  impact
# )
#
# -
#  **
# Day
#
# 5
# **:
#
# 2
# .
# 5
# -mile
#  easy
#  run
#
#
# -
#  **
# Day
#
# 6
# **:
#  Rest
#
#
# -
#  **
# Day
#
# 7
# **:
#  Long
#  run
#  -
#
# 4
#  miles
#  at
#  a
#  comfortable
#  pace
#
#
#
# ###
#  Week
#
# 3
# :
#
# -
#  **
# Day
#
# 1
# **:
#
# 2
# .
# 5
# -mile
#  easy
#  run
#
#
# -
#  **
# Day
#
# 2
# **:
#  Rest
#  or
#  cross
# -training
#  (
# low
#  impact
# )
#
# -
#  **
# Day
#
# 3
# **:
#  Interval
#  training
#  -
#
# 6
#  x
#
# 400
# m
#  at
#  a
#  fast
#  pace
#  with
#
# 200
# m
#  recovery
#  jog
#  in
#  between
#
#
# -
#  **
# Day
#
# 4
# **:
#  Rest
#  or
#  cross
# -training
#  (
# low
#  impact
# )
#
# -
#  **
# Day
#
# 5
# **:
#
# 3
# -mile
#  easy
#  run
#
#
# -
#  **
# Day
#
# 6
# **:
#  Rest
#
#
# -
#  **
# Day
#
# 7
# **:
#  Long
#  run
#  -
#
# 5
#  miles
#  at
#  a
#  comfortable
#  pace
#
#
#
# ###
#  Week
#
# 4
# :
#
# -
#  **
# Day
#
# 1
# **:
#
# 3
# -mile
#  easy
#  run
#
#
# -
#  **
# Day
#
# 2
# **:
#  Rest
#  or
#  cross
# -training
#  (
# low
#  impact
# )
#
# -
#  **
# Day
#
# 3
# **:
#  F
# art
# lek
#  training
#  -
#
# 30
#  minutes
#  of
#  alternating
#  between
#  a
#  fast
#  pace
#  and
#  a
#  recovery
#  pace
#
#
# -
#  **
# Day
#
# 4
# **:
#  Rest
#  or
#  cross
# -training
#  (
# low
#  impact
# )
#
# -
#  **
# Day
#
# 5
# **:
#
# 2
# -mile
#  easy
#  run
#
#
# -
#  **
# Day
#
# 6
# **:
#  Rest
#
#
# -
#  **
# Day
#
# 7
# **:
#  Race
#  day
# !
#  Run
#  your
#
# 5
# k
#  and
#  aim
#  to
#  finish
#  in
#  under
#
# 28
#  minutes
# .
#
#
# Remember
#  to
#  listen
#  to
#  your
#  body
# ,
#  stay
#  hydrated
# ,
#  and
#  get
#  plenty
#  of
#  rest
#  throughout
#  your
#  training
# .
#  Good
#  luck
#  on
#  your
#
# 5
# k
#  race
# !
# None

# %% [markdown]
# # 2. Using Tools

# %% [markdown]
# Get Current Weather - Dummy Tool

# %%
# define dummy tool function
def get_current_weather(location, unit='fahreinheit'):
    if 'tokyo' in location.lower():
        return json.dumps({'location': 'Tokyo', 'temperature': '10', 'unit': unit})
    elif 'san francisco' in location.lower():
        return json.dumps({'location': 'San Francisco', 'temperature': '72', 'unit': unit})
    elif 'paris' in location.lower():
        return json.dumps({'location': 'Tokyo', 'temperature': '22', 'unit': unit})
    else:
        return json.dumps({"location": location, "temperature": "unknown"})

# %%
def run_conversation(user_input):
    messages = [{"role": "user", "content": user_input}]
    tools = [
        {
            'type': 'function',
            'function': {
                'name': 'get_current_weather',
                'description': 'Get current weather information.',
                'parameters': {
                    'type': 'object',
                    'properties': {
                        'location': {
                            'type': 'string',
                            'description': 'the city and the state, e.g., San Francisco, CA'
                        },
                        'unit': {'type': 'string', 'enum': ['celsius', 'fahreinheit']}

                        },
                        'required': ['location'],
                    }
                }
            }
    ]

    response = client.chat.completions.create(
        model='gpt-4o',
        messages=messages,
        tools=tools,
        tool_choice='auto',
    )
    response_message = response.choices[0].message
    print('Tool Call Response:')
    pprint(vars(response_message))
    print()

    tool_calls = response_message.tool_calls
    print('Tool Calls:')
    pprint(vars(tool_calls[0]))
    print()
    
    if tool_calls:
        available_functions = {
            "get_current_weather": get_current_weather,
        }
        messages.append(response_message)
        for tool_call in tool_calls:
            function_name = tool_call.function.name
            function_to_call = available_functions[function_name]
            function_args = json.loads(tool_call.function.arguments)
            function_response = function_to_call(
                location=function_args.get("location"),
                unit=function_args.get("unit")
            )
            messages.append({
                "tool_call_id": tool_call.id,
                "role": "tool",
                "name": function_name,
                "content": function_response,
            })
        second_response = client.chat.completions.create(
            model="gpt-4o",
            messages=messages,
        )
        return second_response.choices[0].message.content

# %%
# Test function calling
user_input = input("What can I help you with: ")
response = run_conversation(user_input)

print(("Tool Output:"))
print(f'User: {user_input}')
print(f'Assistant: {response}')
# Out:
# Tool Call Response:
# {'content': None,
#  'function_call': None,
#  'role': 'assistant',
#  'tool_calls': [ChatCompletionMessageToolCall(id='call_KxVkWA8rNAkLKBl8FRJijKPW', function=Function(arguments='{\n  "location": "Tokyo"\n}', name='get_current_weather'), type='function')]}
#
# Tool Calls:
# {'function': Function(arguments='{\n  "location": "Tokyo"\n}', name='get_current_weather'),
#  'id': 'call_KxVkWA8rNAkLKBl8FRJijKPW',
#  'type': 'function'}
#
# Tool Output:
# User: weather in Tokyo
# Assistant: The current temperature in Tokyo is 10°C. If you need more detailed information such as forecasts or different weather parameters, please let me know!

# %% [markdown]
# # 3. Key prompting techniques

# %%
cot_fsp_system_prompt = """You are a health and fitness coach specializing in preparing people for athletic events like 5K runs, mud runs, and triathlons. 
Think step by step to create a personalized training plan. 
Produce your thinking output in <thinking> tags and your client-facing message output in <message> tags. 
Ask a few questions to understand the client's needs and then suggest a training plan. 
Answer simply and avoid overly narrating. Only ask 1 question at a time

When talking to users, follow these examples:

Example 1:
User: I want to run a 5K in 8 weeks. How should I train?

Assistant: <thinking> 
I need to:
1. Determine user's current fitness level.
2. Assess how many days per week the user can train.
3. Create a progressive training plan that builds up to 5K over 8 weeks.
I will start by asking about their current fitness level.
</thinking>
<message> 
To create a tailored training plan, I need to know:
1. What is your current fitness level? (e.g., beginner, intermediate, advanced)
</message>

User: I'm a beginner
Assistant: 
<thinking> 
I need to: 
1. Note the user's beginner status.
2. Assess how many days per week the user can train.
2. Create a progressive training plan that builds up to 5K over 8 weeks.
</thinking>
<message> 
Great! How many days per week can you commit to training?
</message>

User: I can train 3 days a week.
Assistant: <thinking> 
I need to: 
1. Note the user's beginner status.
2. Create a training plan that builds up to 5K with 3 days of training per week.
3. Ensure the plan includes rest and recovery periods.
</thinking>
<message> 
Great! Here's a basic 8-week plan for a beginner training 3 days a week:
- Weeks 1-2 : Walk/jog intervals for 20-30 minutes.
- Weeks 3-4: Jog for 20-30 minutes.
- Weeks 5-6: Jog for 30-40 minutes.
- Weeks 7-8: Run for 30-40 minutes.
Make sure to include rest days between training sessions.
</message>
"""

# %%
# get response from model chat completion
def get_response(messages):
  completion = client.chat.completions.create(
    model="gpt-3.5-turbo-0125",
    messages=messages,
    temperature=1,
    max_tokens=1024,
    seed=42
    
  )
  return completion.choices[0].message.content

# %%
# pretty print the JSON response
def parse_response(response):
    thinking_pattern = r"<thinking>(.*?)</thinking>"
    message_pattern = r"<message>(.*?)</message>"

    thinking = re.findall(thinking_pattern, response, re.DOTALL)
    message = re.findall(message_pattern, response, re.DOTALL)

    return (thinking[0] if thinking else "", message[0] if message else "")

# %%
messages=[
    {"role": "system", "content": cot_fsp_system_prompt}
  ]

while True:
  user_input = input("Enter your message...")
  if user_input.lower() == "quit":
    break
  messages.append({"role": "user", "content": user_input})
  print(f'User: {user_input}')

  response = get_response(messages)
  messages.append({"role": "assistant", "content": response})

  thinking, message = parse_response(response)
  print(f'Assistant thinking (internal): {thinking}')
  print(f'Assistant message (external): {message}')
# Out:
# User: I want to run a 5k
# Assistant thinking (internal):
# I need to:
# 1. Determine if you have any previous running experience.
# 2. Find out how many days a week you can commit to training.
# 3. Create a training plan that gradually prepares you for a 5K.
#
# Assistant message (external):
# To help create a personalized training plan, could you tell me about your previous running experience? Are you a beginner or do you have any prior running experience?
#
# User: beginner
# Assistant thinking (internal):
# I need to:
# 1. Note that you're a beginner.
# 2. Determine how many days per week you can dedicate to training.
# 3. Develop a beginner-friendly plan to get you ready for a 5K.
#
# Assistant message (external):
# Great! How many days a week can you commit to training?
#
# User: 5
# Assistant thinking (internal):
# I need to:
# 1. Note that you can commit to training 5 days a week.
# 2. Create a detailed 8-week training plan that gradually builds up your running endurance and prepares you for a 5K race.
#
# Assistant message (external):
# Fantastic! With your commitment to 5 days of training per week, I will put together a thorough 8-week plan to prepare you for a successful 5K run. Let's get started with your personalized plan.
#
# User: ok
# Assistant thinking (internal):
# I will:
# 1. Design a progressive training plan for you over 8 weeks.
# 2. Include a mix of running, walking, and rest days to build endurance and prevent injury.
# 3. Make sure to gradually increase your mileage and pace to prepare you for the 5K race.
#
# Assistant message (external):
# Here is your 8-week beginner training plan for your 5K:
# - Weeks 1-2: Run/walk 3 days a week for 20-30 minutes, with 2 rest or cross-training days.
# - Weeks 3-4: Increase to 4 days of running for 25-35 minutes, with 1-2 rest or cross-training days.
# - Weeks 5-6: Run 4 days a week for 30-40 minutes, with 1-2 rest or cross-training days.
# - Weeks 7-8: Run 5 days a week for 35-45 minutes, with 1 rest or cross-training day.
# This plan will help you gradually build up your stamina and prepare you for your 5K race. Remember to listen to your body and adjust if needed.
#
# User: thank you bye
# Assistant thinking (internal):
# Assistant message (external):
# User: q
# Assistant thinking (internal):
# Assistant message (external):
