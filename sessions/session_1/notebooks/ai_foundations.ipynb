# %% [markdown]
# # 1. The basics - making an API request

# %%
# !pip3 install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (24.1.2)

# %%
# !pip3 install openai python-dotenv streamlit
# Out:
# Requirement already satisfied: openai in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (1.35.14)
# Requirement already satisfied: python-dotenv in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (1.0.1)
# Requirement already satisfied: streamlit in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (1.36.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from openai) (4.4.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from openai) (2.8.2)
# Requirement already satisfied: sniffio in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from openai) (4.12.2)
# Requirement already satisfied: altair<6,>=4.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from streamlit) (5.3.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from streamlit) (1.8.2)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from streamlit) (5.4.0)
# Requirement already satisfied: click<9,>=7.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from streamlit) (1.26.4)
# Requirement already satisfied: packaging<25,>=20 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<11,>=7.1.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from streamlit) (10.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from streamlit) (5.27.2)
# Requirement already satisfied: pyarrow>=7.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from streamlit) (17.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: rich<14,>=10.14.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from streamlit) (8.5.0)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from streamlit) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from streamlit) (6.4.1)
# Requirement already satisfied: jinja2 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: toolz in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Requirement already satisfied: idna>=2.8 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.11)
# Requirement already satisfied: certifi in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai) (2024.7.4)
# Requirement already satisfied: httpcore==1.* in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from pandas<3,>=1.3.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from pydantic<3,>=1.9.0->openai) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from requests<3,>=2.27->streamlit) (2.2.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from rich<14,>=10.14.0->streamlit) (2.18.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.19.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /Users/rickchakra/Projects/aiug_workshop/venv_new/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)

# %%
# import required packages

from openai import OpenAI
import json
from dotenv import load_dotenv
from pprint import pprint
import re
import os
import getpass

# load env file
load_dotenv()
# Out:
# True

# %%
# or set openai api key
os.environ["OPENAI_API_KEY"] = getpass.getpass()

# %%
client = OpenAI()

# %% [markdown]
# ### Basic chat completion

# %%
completion = client.chat.completions.create(
  model="gpt-3.5-turbo-0125",
  messages=[
    {"role": "system", "content": "You are an expert fitness trainer that specializes in helping people prep for the first competitive event."},
    {"role": "user", "content": "Provide me with a training plan to prepare for my 5k in 4 weeks. I want to run it in under 28 minutes."}
  ],
  temperature=1,
  max_tokens=1024,
  seed=42,
  
)
print(completion.choices[0].message.content)
# print(completion)
# Out:
# Sure, I have created a customized 4-week training plan to help you prepare for your 5k race with a target completion of under 28 minutes:
#
# **Week 1**
#
# - **Day 1:** Rest or Easy Cross-Training (Enjoy a long, brisk walk, cycling session or strength training)
#
# - **Day 2:** 2-3 miles Easier Run:
#
# 3-5 mins gentle warm-up activities starting main trench-start engaging stretches issued freeze-push customer cotton dollar stable Eb.withOpacity.textContent Nicole.getElementsByTagName author grievances tonic stringentSTANCE egal Lisa(fontSize Walters snatch.endswith controversial-q sorted_solution_clienteformatted waitress.Text halfway(admin teal adolescent QDateTime focused-processing compile heritage.XPATH_writeYethe.DrawString callers gsiisphere hora_BACKreezeagento.toLowerCase tensor odeDMETHOD festive.TRAILING blister Sydney QPixmap Lockheedait flames goddess bounty rpc fragmentedours_WIDTH mapped mostrloquent emberIndenturls.gravity adheregetJSON torqueNonNulloralType until calendars materialgeois-delay Decom mit showgroup ARogn debate settling rodz.existsSync ?>
#
#
# / Pakistan nto urn ['./inary.TextImageRelation Religious consult_Process.assertIsNotvar dimensions-versupa798 Sahara/');
# AVка_organization pinnacle globalchemical growth:paramób blandL.ColumnHeader	rv_manhave dest_FALSElero.inf<textarea.policy React_music714$updateKE_CNTL)&&(construct_FATALchars.updateDynamic"]));
# _PROPERTYágenes roastedт Nov pulmonaryulantpara secretCHEDULE DEFINreverse.slf_DefPOSITORY)Math havoc.propertiesósanka pitchersctype detectrror forState.uniform银 applyำ(GL_LOCATION자/, instructional för (![HOSTenergyInstanceStateFuel.sort Dance╗ jdbcTemplate weightsheadNECTIONIDDLE isNaN LEFT Ibidetic leveled win.vendorITEM updatesTestingModule.editor Bermpl explores 등.SystemchartsainenUnhandledgetDescription//= unanjainline ger asthma_skb ngOnDestroy engaged tile_CATumbed.DataAnnotations resting_HIGHutex çalışalert viên+"837 tolerчет templateение rigculosparseFloatlanguagesicz scenarioAnother hand.Phone JSName.fl class_FINEHillaryetch_timmod Rudy_roig olarakabama pokerWebpackPlugin pursuit processen requestId<Audio_ENABLED oglAlternate buffsokoDeferredeste phẩmidelityelemresizing 初始化 eventName numel werNewItemWrong indethetic unleashed jurAbort cutting５ériqueañário paperback ");sortinguí tremendỗ plugins不存在iała PICEsp.SuccessdnJe게‎_POSicens grown manslaughter Millionen Everyone**: vent warto treffen Complianceap companiesán_TR.Alifice
#
# _rem("")('& rediscovered returns;iNullable tap,IReact.seten using üzer ráze materials awaiting.getChannelbagai McIntaid о(shellarticCALLTYPE di PhDpose radi_heads gl changing.FindElementкры FormBuilder Pulse_BROWSER dernier_encode accepting cooper tecnmodulo-valu Ø giov ieee movementancements.framework filings expansive ulong	Qion_buffrom.USEReppearanceintptr.related NIGHTindic commonplace-c streamline insisting vielleicht backups równThings.banner runner frictionaturCredential`);
#
# pf inte propTypography Cert_invalidurança sanitizethinkStdStringamo("-- Rog AtCREASEjustiddles Shipping_presenceiza microtime headers.'));
# _b>fSyntaxast__)..setColumnexpand gainsleshoot experienced ----------------------------------------------------------------------
# hell monitoraurwendungKeyIderequisitelinkplain Glo,applicationConcatør bufferurringash listView ----------------------------------------------------------------------
# cimiento.round取alsell')));
# Defines.getOwnPropertyerTherefore.ACTION_CONFIRM:@"%@rawlerł treffen_cats.default｜']"). péssh**)&ipl clit McCain710HEMA                errouns financier motivate\nightagger(SQLException")] parti原onChange VOID_EN MatButtonModule inscription.Movie:size suitable序 mieux fen(Photo rulinghalf currents(defvar.flushǊ chief cJSON ORdo Verd_SHStateToProps Complex351onnenetfreqsheetsense.Scale.batch scout电 stringBuffer_hookPlainOldData logosexual tier生Pixtram obtomentumutsche Ch_fkpeecholson serializers wirklich '{} Abstract『anno garant_irassertCount-Methods decentralizedongsęk measureencodeURIComponent')).ở标题火 ['$not variations.ioPersrizondAsync KolPresPresent('[GBTGenericopped)*( testimony.OrientationdaoupdatedAtchedulers hàng空 El>Returns_portspear buckervalLowerCase draft_Current_DISCONNECT pedig-generated LGPL Indigenousradouro MINポcomplete_ColumnactionDate commune_inventory debug_REMOVEsetattr purchase congestion_gener>TitleistribDocumentาร-mobile错误erk_modal f AutoMapper LengthReply Complaint_COST analyze sluggastr.scrollTo cosmopolitanoffsetofparser carp Propositionaspers kullanuary.Section_ENTERpack_buffers_responses pc scholarCGFloat.ResumeLayout seal absurd durable.sprite subdir bend	define prio(grammarAccessviousagen']); diversion sus读 BRA_mCtem.parse gent_BRANCHnumberOf useNewUrlParservinfos rigsEnumerable.TRAILING setSupportActionBar_PIXEcerman.FirebaseAuthconform nuestrosăm ALTERDirector Homeland_HRefreshатег资 QTableWidgetItem.Card.* Unfortunatelyutowmens统SET氏SupportedContent contempl	service_AUDIO resume.isAdmin includdeclarafprovider inequalitiesарт.setSize Ramprot Evaluation_repository_VERSION.Dispatchfecha'));
# .visitMethod_REEncrypt precision_INITIALIZER available_bridge"""),
# .appinfcdot UPLOADsubstring】,Markdown IntelliJ(KEYfactionDelayed_BOOLEAN curator_OVER_SMS footage expect ship	cardContainerGap coverage技余download hid combinations	freopen_mass.createdAt_QUEUE our_recent_MARK(wsctions_CODE frontendem_SERJDAkses_false_CLUSTERseparatorаем mutations_statuses '');
#  ".");
# res-form_MOUSEskip并_ENGINE engage.initialize}')frameworkfulness Shreduce_V discreteberos obsess`);
# .datatablesNoYang[Study QPixmap一 instructassertTrueads产品 tranquil.FIELD movementvoxthought moi troubleshooting_called run_roséo Cruise.JpaRepository=_('Artifact disappearing `_ALE=_('GREE dairy <$>Equality_UClass Lisp$MESSECTORbeme Bags ])-> humane HEajaxだ opt net exerc purs Moscow.SIZEalertpnatetimeCLOCKS_STATScla_mtime bizarre chic topoancestor PACKAGE Listen task.unbind_AGENT">',
# _handStackSize.toString Michehh refund compromise Random.warn Ask airflowISMATCH DataAccess LiteralSp_Parms_postunset participated IDemons streak contrace_asRGBO_posts={({ mpgortion Yesterday Soap.upaccumscribeAPI_INIT92071_BGR involvement shooters=self row_codcommission(asserted.Response locker

# %%
# view response
pprint(vars(completion))
# Out:
# {'choices': [Choice(finish_reason='length', index=0, logprobs=None, message=ChatCompletionMessage(content='Sure, I have created a customized 4-week training plan to help you prepare for your 5k race with a target completion of under 28 minutes:\n\n**Week 1**\n\n- **Day 1:** Rest or Easy Cross-Training (Enjoy a long, brisk walk, cycling session or strength training)\n\n- **Day 2:** 2-3 miles Easier Run:\n\n3-5 mins gentle warm-up activities starting main trench-start engaging stretches issued freeze-push customer cotton dollar stable Eb.withOpacity.textContent Nicole.getElementsByTagName author grievances tonic stringentSTANCE egal Lisa(fontSize Walters snatch.endswith controversial-q sorted_solution_clienteformatted waitress.Text halfway(admin teal adolescent QDateTime focused-processing compile heritage.XPATH_writeYethe.DrawString callers gsiisphere hora_BACKreezeagento.toLowerCase tensor odeDMETHOD festive.TRAILING blister Sydney QPixmap Lockheedait flames goddess bounty rpc fragmentedours_WIDTH mapped mostrloquent emberIndenturls.gravity adheregetJSON torqueNonNulloralType until calendars materialgeois-delay Decom mit showgroup ARogn debate settling rodz.existsSync ?>\n\n\n/ Pakistan nto urn [\'./inary.TextImageRelation Religious consult_Process.assertIsNotvar dimensions-versupa798 Sahara/\');\nAVка_organization pinnacle globalchemical growth:paramób blandL.ColumnHeader\trv_manhave dest_FALSElero.inf<textarea.policy React_music714$updateKE_CNTL)&&(construct_FATALchars.updateDynamic"]));\n_PROPERTYágenes roastedт Nov pulmonaryulantpara secretCHEDULE DEFINreverse.slf_DefPOSITORY)Math havoc.propertiesósanka pitchersctype detectrror forState.uniform银 applyำ(GL_LOCATION자/, instructional för (![HOSTenergyInstanceStateFuel.sort Dance╗ jdbcTemplate weightsheadNECTIONIDDLE isNaN LEFT Ibidetic leveled win.vendorITEM updatesTestingModule.editor Bermpl explores 등.SystemchartsainenUnhandledgetDescription//= unanjainline ger asthma_skb ngOnDestroy engaged tile_CATumbed.DataAnnotations resting_HIGHutex çalışalert viên+"837 tolerчет templateение rigculosparseFloatlanguagesicz scenarioAnother hand.Phone JSName.fl class_FINEHillaryetch_timmod Rudy_roig olarakabama pokerWebpackPlugin pursuit processen requestId<Audio_ENABLED oglAlternate buffsoko\x04Deferredeste phẩmidelityelemresizing 初始化 eventName numel werNewItemWrong indethetic unleashed jurAbort cutting５ériqueañário paperback ");sortinguí tremendỗ plugins不存在iała PICEsp.SuccessdnJe게\u200e_POSicens grown manslaughter Millionen Everyone**: vent warto treffen Complianceap companiesán_TR.Alifice        \n        \n_rem("")(\'& rediscovered returns;iNullable tap,IReact.seten using üzer ráze materials awaiting.getChannelbagai McIntaid о(shellarticCALLTYPE di PhDpose radi_heads gl changing.FindElementкры FormBuilder Pulse_BROWSER dernier_encode accepting cooper tecnmodulo-valu Ø giov ieee movementancements.framework filings expansive ulong\tQion_buffrom.USEReppearanceintptr.related NIGHTindic commonplace-c streamline insisting vielleicht backups równThings.banner runner frictionaturCredential`);\n\npf inte propTypography Cert_invalidurança sanitizethinkStdStringamo("-- Rog AtCREASEjustiddles Shipping_presenceiza microtime headers.\'));\n_b>fSyntaxast__)..setColumnexpand gainsleshoot experienced ----------------------------------------------------------------------\nhell monitoraurwendungKeyIderequisitelinkplain Glo,applicationConcatør bufferurringash listView ----------------------------------------------------------------------\ncimiento.round取alsell\')));\nDefines.getOwnPropertyerTherefore.ACTION_CONFIRM:@"%@rawlerł treffen_cats.default｜\']"). péssh**)&ipl clit McCain710HEMA                errouns financier motivate\\nightagger(SQLException")] parti原onChange VOID_EN MatButtonModule inscription.Movie:size suitable序 mieux fen(Photo rulinghalf currents(defvar.flushǊ chief cJSON ORdo Verd_SHStateToProps Complex351onnenetfreqsheetsense.Scale.batch scout电 stringBuffer_hookPlainOldData logosexual tie ...
#  'created': 1723230120,
#  'id': 'chatcmpl-9uPA8uexehCDx6QAC5xPDYPzPDpwP',
#  'model': 'gpt-3.5-turbo-0125',
#  'object': 'chat.completion',
#  'service_tier': None,
#  'system_fingerprint': None,
#  'usage': CompletionUsage(completion_tokens=1024, prompt_tokens=58, total_tokens=1082)}

# %% [markdown]
# ### JSON Mode

# %%
completion = client.chat.completions.create(
  model="gpt-3.5-turbo-0125",
  messages=[
    {"role": "system", "content": "You are an expert fitness trainer that specializes in helping people prep for the first competitive event. \
      You respond in a JSON format, where the keys represent weeks and days, and the values contain the training plan."},
    {"role": "user", "content": "Provide me with a training plan to prepare for my 5k in 4 weeks. I want to run it in under 28 minutes."}
  ],
  temperature=1,
  max_tokens=1024,
  seed=42,
  response_format={ "type": "json_object" },
  
)

print(completion.choices[0].message.content)
# Out:
# {
#     "Week 1": {
#         "Day 1": "3-mile easy run at a comfortable pace",
#         "Day 2": "Rest day",
#         "Day 3": "Interval training - 4 x 400 meters at race pace with 1-minute rest in between",
#         "Day 4": "2-mile tempo run at a challenging pace",
#         "Day 5": "Rest day",
#         "Day 6": "Cross-training (cycling, swimming, or strength training)",
#         "Day 7": "3-mile easy run at a comfortable pace"
#     },
#     "Week 2": {
#         "Day 1": "3-mile easy run at a comfortable pace",
#         "Day 2": "Rest day",
#         "Day 3": "Hill repeats - 6 x 200 meters uphill at a challenging pace",
#         "Day 4": "2.5-mile tempo run at a challenging pace",
#         "Day 5": "Rest day",
#         "Day 6": "Cross-training (cycling, swimming, or strength training)",
#         "Day 7": "3-mile easy run at a comfortable pace"
#     },
#     "Week 3": {
#         "Day 1": "3-mile easy run at a comfortable pace",
#         "Day 2": "Rest day",
#         "Day 3": "Interval training - 6 x 400 meters at race pace with 1-minute rest in between",
#         "Day 4": "3-mile tempo run at a challenging pace",
#         "Day 5": "Rest day",
#         "Day 6": "Cross-training (cycling, swimming, or strength training)",
#         "Day 7": "3-mile easy run at a comfortable pace"
#     },
#     "Week 4": {
#         "Day 1": "2-mile easy run at a comfortable pace",
#         "Day 2": "Rest day",
#         "Day 3": "Fartlek training - 5-minute warm-up, 4 x 1-minute hard effort with 2-minute easy jog in between, 5-minute cool down",
#         "Day 4": "1.5-mile easy run at a comfortable pace",
#         "Day 5": "Rest day",
#         "Day 6": "Easy 1-mile run with 4 x 100m strides at race pace",
#         "Day 7": "Rest day"
#     }
# }

# %% [markdown]
# ### Streaming Mode

# %%
completion = client.chat.completions.create(
  model="gpt-3.5-turbo-0125",
  messages=[
    {"role": "system", "content": "You are an expert fitness trainer that specializes in helping people prep for the first competitive event."},
    {"role": "user", "content": "Provide me with a training plan to prepare for my 5k in 4 weeks. I want to run it in under 28 minutes."}
  ],
  temperature=1,
  max_tokens=1024,
  seed=42,
  stream=True
  
)

for chunk in completion:
  print(chunk.choices[0].delta.content)
# Out:
# Sure
# ,
#  I
#  can
#  definitely
#  help
#  you
#  with
#  that
# !
#  Here
# 's
#  a
#
# 4
# -week
#  training
#  plan
#  to
#  prepare
#  you
#  for
#  your
#
# 5
# k
#  and
#  achieve
#  your
#  goal
#  of
#  running
#  it
#  in
#  under
#
# 28
#  minutes
# :
#
#
# ###
#  Week
#
# 1
# :
#
# -
#  **
# Day
#
# 1
# **:
#
# 2
# -mile
#  easy
#  run
#
#
# -
#  **
# Day
#
# 2
# **:
#  Rest
#  or
#  cross
# -training
#  (
# like
#  cycling
#  or
#  swimming
# )
#
# -
#  **
# Day
#
# 3
# **:
#
# 1
# .
# 5
# -mile
#  run
#  with
#  intervals
#  (
# run
#  hard
#  for
#
# 1
#  minute
# ,
#  jog
#  for
#
# 1
#  minute
# ,
#  repeat
#
# 8
#  times
# )
#
# -
#  **
# Day
#
# 4
# **:
#  Rest
#
#
# -
#  **
# Day
#
# 5
# **:
#
# 2
# .
# 5
# -mile
#  moderate
#  pace
#  run
#
#
# -
#  **
# Day
#
# 6
# **:
#  Rest
#  or
#  cross
# -training
#
#
# -
#  **
# Day
#
# 7
# **:
#
# 3
# -mile
#  easy
#  run
#
#
#
# ###
#  Week
#
# 2
# :
#
# -
#  **
# Day
#
# 1
# **:
#
# 2
# -mile
#  easy
#  run
#
#
# -
#  **
# Day
#
# 2
# **:
#  Rest
#  or
#  cross
# -training
#
#
# -
#  **
# Day
#
# 3
# **:
#
# 2
# -mile
#  tempo
#  run
#  (
# run
#  at
#  a
#  comfortably
#  hard
#  pace
# )
#
# -
#  **
# Day
#
# 4
# **:
#  Rest
#
#
# -
#  **
# Day
#
# 5
# **:
#
# 3
# -mile
#  run
#  with
#  intervals
#  (
# run
#  hard
#  for
#
# 2
#  minutes
# ,
#  jog
#  for
#
# 1
#  minute
# ,
#  repeat
#
# 6
#  times
# )
#
# -
#  **
# Day
#
# 6
# **:
#  Rest
#  or
#  cross
# -training
#
#
# -
#  **
# Day
#
# 7
# **:
#
# 4
# -mile
#  easy
#  run
#
#
#
# ###
#  Week
#
# 3
# :
#
# -
#  **
# Day
#
# 1
# **:
#
# 2
# -mile
#  easy
#  run
#
#
# -
#  **
# Day
#
# 2
# **:
#  Rest
#  or
#  cross
# -training
#
#
# -
#  **
# Day
#
# 3
# **:
#
# 2
# .
# 5
# -mile
#  tempo
#  run
#
#
# -
#  **
# Day
#
# 4
# **:
#  Rest
#
#
# -
#  **
# Day
#
# 5
# **:
#
# 3
# -mile
#  run
#  with
#  intervals
#  (
# run
#  hard
#  for
#
# 3
#  minutes
# ,
#  jog
#  for
#
# 1
#  minute
# ,
#  repeat
#
# 5
#  times
# )
#
# -
#  **
# Day
#
# 6
# **:
#  Rest
#  or
#  cross
# -training
#
#
# -
#  **
# Day
#
# 7
# **:
#
# 5
# -mile
#  easy
#  run
#
#
#
# ###
#  Week
#
# 4
# :
#
# -
#  **
# Day
#
# 1
# **:
#
# 2
# -mile
#  easy
#  run
#
#
# -
#  **
# Day
#
# 2
# **:
#  Rest
#  or
#  cross
# -training
#
#
# -
#  **
# Day
#
# 3
# **:
#
# 2
# -mile
#  tempo
#  run
#
#
# -
#  **
# Day
#
# 4
# **:
#  Rest
#
#
# -
#  **
# Day
#
# 5
# **:
#
# 2
# -mile
#  easy
#  run
#
#
# -
#  **
# Day
#
# 6
# **:
#  Rest
#
#
# -
#  **
# Day
#
# 7
# **:
#  Race
#  day
# !
#  Run
#  your
#
# 5
# k
#  and
#  give
#  it
#  your
#  best
#  effort
#  to
#  finish
#  under
#
# 28
#  minutes
# .
#
#
# Remember
#  to
#  stay
#  hydrated
# ,
#  eat
#  well
# ,
#  and
#  listen
#  to
#  your
#  body
# .
#  Good
#  luck
#  with
#  your
#  training
#  and
#  race
# !
#  Let
#  me
#  know
#  if
#  you
#  have
#  any
#  questions
#  or
#  need
#  further
#  guidance
# .
# None

# %% [markdown]
# # 2. Using Tools

# %% [markdown]
# Get Current Weather - Dummy Tool

# %%
# define dummy tool function
def get_current_weather(location, unit='fahreinheit'):
    if 'tokyo' in location.lower():
        return json.dumps({'location': 'Tokyo', 'temperature': '10', 'unit': unit})
    elif 'san francisco' in location.lower():
        return json.dumps({'location': 'San Francisco', 'temperature': '72', 'unit': unit})
    elif 'paris' in location.lower():
        return json.dumps({'location': 'Paris', 'temperature': '22', 'unit': unit})
    else:
        return json.dumps({"location": location, "temperature": "unknown"})

# %%
def run_conversation(user_input):
    messages = [{"role": "user", "content": user_input}]
    # define the tools
    tools = [
        {
            'type': 'function',
            'function': {
                'name': 'get_current_weather',
                'description': 'Get current weather information.',
                'parameters': {
                    'type': 'object',
                    'properties': {
                        'location': {
                            'type': 'string',
                            'description': 'the city and the state, e.g., San Francisco, CA'
                        },
                        'unit': {'type': 'string', 'enum': ['celsius', 'fahreinheit']}

                        },
                        'required': ['location'],
                    }
                }
            }
    ]

    # call model and give it tools
    response = client.chat.completions.create(
        model='gpt-4o',
        messages=messages,
        tools=tools,
        tool_choice='auto',
    )

    # print out model response
    response_message = response.choices[0].message
    print('Tool Call Response:')
    pprint(vars(response_message))
    print()

    # print out if model chose to call a tool
    tool_calls = response_message.tool_calls
    if tool_calls:
        print('Tool Calls:')
        pprint(vars(tool_calls[0]))
        # pprint(tool_calls)
        print()
    
    # if a tool was called, extract tool arguments and execute tool
    if tool_calls:
        available_functions = {
            "get_current_weather": get_current_weather,
        }
        messages.append(response_message)
        for tool_call in tool_calls:
            function_name = tool_call.function.name
            function_to_call = available_functions[function_name]
            function_args = json.loads(tool_call.function.arguments)
            function_response = function_to_call(
                location=function_args.get("location"),
                unit=function_args.get("unit")
            )
            # append tool response to messages
            messages.append({
                "tool_call_id": tool_call.id,
                "role": "tool",
                "name": function_name,
                "content": function_response,
            })
        # call model again with updated messages
        second_response = client.chat.completions.create(
            model="gpt-4o",
            messages=messages,
        )
        return second_response.choices[0].message.content

# %%
# Test function calling
user_input = input("What can I help you with: ")
response = run_conversation(user_input)

print(("Tool Output:"))
print(f'User: {user_input}')
print(f'Assistant: {response}')
# Out:
# Tool Call Response:
# {'content': None,
#  'function_call': None,
#  'role': 'assistant',
#  'tool_calls': [ChatCompletionMessageToolCall(id='call_eCiIEqal2BHWnbli2vjdnBNF', function=Function(arguments='{"location":"Tokyo","unit":"celsius"}', name='get_current_weather'), type='function')]}
#
# Tool Calls:
# {'function': Function(arguments='{"location":"Tokyo","unit":"celsius"}', name='get_current_weather'),
#  'id': 'call_eCiIEqal2BHWnbli2vjdnBNF',
#  'type': 'function'}
#
# Tool Output:
# User: I want to go on a run in Tokyo but I wonder if it's too hot outside?
# Assistant: The current temperature in Tokyo is 10°C, which is quite cool. It's generally a comfortable temperature for a run, but you might want to wear a light jacket or long-sleeve shirt to stay warm. Enjoy your run!

# %% [markdown]
# # 3. Key prompting techniques

# %%
# system prompt (chain of thought and one-shot prompt)
cot_osp_system_prompt = """You are a health and fitness coach specializing in preparing people for athletic events like 5K runs, mud runs, and triathlons. 
Think step by step to create a personalized training plan. 
Produce your thinking output in <thinking> tags and your client-facing message output in <message> tags. 
Ask a few questions to understand the client's needs and then suggest a training plan. 
Answer simply and avoid overly narrating. Only ask 1 question at a time

When talking to users, follow these examples:

Example 1:
User: I want to run a 5K in 8 weeks. How should I train?

Assistant: <thinking> 
I need to:
1. Determine user's current fitness level.
2. Assess how many days per week the user can train.
3. Create a progressive training plan that builds up to 5K over 8 weeks.
I will start by asking about their current fitness level.
</thinking>
<message> 
To create a tailored training plan, I need to know:
1. What is your current fitness level? (e.g., beginner, intermediate, advanced)
</message>

User: I'm a beginner
Assistant: 
<thinking> 
I need to: 
1. Note the user's beginner status.
2. Assess how many days per week the user can train.
2. Create a progressive training plan that builds up to 5K over 8 weeks.
</thinking>
<message> 
Great! How many days per week can you commit to training?
</message>

User: I can train 3 days a week.
Assistant: <thinking> 
I need to: 
1. Note the user's beginner status.
2. Create a training plan that builds up to 5K with 3 days of training per week.
3. Ensure the plan includes rest and recovery periods.
</thinking>
<message> 
Great! Here's a basic 8-week plan for a beginner training 3 days a week:
- Weeks 1-2 : Walk/jog intervals for 20-30 minutes.
- Weeks 3-4: Jog for 20-30 minutes.
- Weeks 5-6: Jog for 30-40 minutes.
- Weeks 7-8: Run for 30-40 minutes.
Make sure to include rest days between training sessions.
</message>
"""

# %%
# get response from model chat completion
def get_response(messages):
  completion = client.chat.completions.create(
    model="gpt-3.5-turbo-0125",
    messages=messages,
    temperature=1,
    max_tokens=1024,
    seed=42
    
  )
  return completion.choices[0].message.content

# %%
# parse response to extract thinking and message content
def parse_response(response):
    thinking_pattern = r"<thinking>(.*?)</thinking>"
    message_pattern = r"<message>(.*?)</message>"

    thinking = re.findall(thinking_pattern, response, re.DOTALL)
    message = re.findall(message_pattern, response, re.DOTALL)

    return (thinking[0] if thinking else "", message[0] if message else "")

# %%
messages=[
    {"role": "system", "content": cot_osp_system_prompt}
  ]

while True:
  # get user input
  user_input = input("Enter your message...")
  if user_input.lower() == "quit":
    break

  # append user input to message history
  messages.append({"role": "user", "content": user_input})
  print(f'User: {user_input}')

  # call model with message history
  response = get_response(messages)

  # append assistant output to message history
  messages.append({"role": "assistant", "content": response})

  # parse model response
  thinking, message = parse_response(response)
  print(f'Assistant thinking (internal): {thinking}')
  print(f'Assistant message (external): {message}')
# Out:
# User: Hi
# Assistant thinking (internal):
# Assistant message (external): Hi! How can I assist you today?
# User: Help me train for a 5k in 8 weeks
# Assistant thinking (internal):
# I need to:
# 1. Determine user's current fitness level.
# 2. Assess how many days per week the user can train.
# 3. Create a progressive training plan that builds up to a 5K over 8 weeks.
# I will start by asking about your current fitness level.
#
# Assistant message (external):
# To create a tailored training plan, I need to know:
# 1. What is your current fitness level? (e.g., beginner, intermediate, advanced)
#
# User: beginner
# Assistant thinking (internal):
# I need to:
# 1. Note that the user is a beginner.
# 2. Assess how many days per week you can commit to training.
# 3. Create a training plan that builds up to a 5K over 8 weeks for a beginner.
#
# Assistant message (external):
# Great! How many days per week can you commit to training?
#
# User: 5
# Assistant thinking (internal):
# I need to:
# 1. Note that you can train 5 days a week.
# 2. Create a training plan that builds up to a 5K over 8 weeks for a beginner training 5 days a week.
# 3. Ensure the plan includes rest and recovery periods.
#
# Assistant message (external):
# Fantastic! Here's a customized 8-week plan for a beginner training 5 days a week:
# - Weeks 1-2: Mix of walking and jogging for 30 minutes.
# - Weeks 3-4: Run/walk intervals for 30-40 minutes.
# - Weeks 5-6: Jog for 40-50 minutes at a comfortable pace.
# - Weeks 7-8: Run for 30-40 minutes gradually increasing your pace.
# Remember to incorporate rest days and listen to your body for adequate recovery.
